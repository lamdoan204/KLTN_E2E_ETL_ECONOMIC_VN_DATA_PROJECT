# %%
from minio import Minio

# %%
client = Minio(
    'localhost:9000',
    access_key = 'minioadmin',
    secret_key= 'minioadmin',
    secure= False
)

# %%
# Out:
# economic_report_excel_files/2025/1/02-Bieu-T01.2025-2.xlsx
# economic_report_excel_files/2025/10/02.-So-lieu-T10.2025.xlsx
# economic_report_excel_files/2025/11/2.-So-lieu-T11.2025.xlsx
# economic_report_excel_files/2025/12/02.-Bieu-12.2025-4.xlsx
# economic_report_excel_files/2025/2/Bieu-T2.2025-2.xlsx
# economic_report_excel_files/2025/3/02-Bieu-T3.2025-final.xlsx
# economic_report_excel_files/2025/4/02-Bieu-T4.2025-final.xlsx
# economic_report_excel_files/2025/5/2.-Bieu-thang-5.2025.xlsx
# economic_report_excel_files/2025/6/2.-So-lieu-6-thang-2025.xlsx
# economic_report_excel_files/2025/7/02-Bieu-T7.2025-final.xlsx
# economic_report_excel_files/2025/8/02-So-lieu-T8.2025.xlsx
# economic_report_excel_files/2025/9/02.-Bieu-T9.2025-final.xlsx
# economic_report_excel_files/2026/1/02.-Bieu-T1.2026.xlsx
# economic_report_excel_files/2026/2/02.-Bieu-T2.xlsx
# economic_report_excel_files/2026/3/02.-Bieu-T3.2026-1.xlsx

# %%
from minio import Minio
import pandas as pd
import io

client = Minio(
    "localhost:9000",
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False
)

obj = client.get_object(
    "bronze",
    "economic_report_excel_files/2026/3/02.-Bieu-T3.2026-1.xlsx"
)

data = obj.read()

excel_file = pd.ExcelFile(io.BytesIO(data))

# %%
print(excel_file.sheet_names)
# Out:
# ['1.GDP ', '2.SXNN', '3.Chan nuoi', '4.Lam nghiep', '5. Thuy san', '6.IIP', '7.SPCN', '8.CSTTTK', '9.LĐCN', '10. LĐCN_DP', '11.Chi tieu DN', '12. DN DK thanh lap', '13. DN quay lai hoat dong', '14. DN Ngừng có thời hạn', '15. DN giải thể', '16.VonDTTXH', '17.VonDT', '18.FDI', '19. Tongmuc', '20.XK tháng', '21.NK tháng', '22.XNK Dich vu', '23. CPI', '24.Gia SX', '25.Gia NVL', '26.Gia Van tai', '27.Gia XK', '28.Gia NK', '29.TygiaTM', '30.VT HK', '31. VT HH', '32. Khach QT', '33.34.LĐ, That nghiep ', '35. LĐPCT', '36.XHMT']

# %%
sheet = pd.read_excel(excel_file, excel_file.sheet_names[0], header= None)
sheet
# Out:
#                                                     0  \
# 0   1. Tổng sản phẩm trong nước ước tính quý I năm...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                             TỔNG SỐ
# 8                        Nông, lâm nghiệp và thủy sản
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                            Công nghiệp và xây dựng
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                            Dịch vụ
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                 Thuế sản phẩm trừ trợ cấp sản phẩm
#
#                                                     1                   2  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN  Theo giá hiện hành
# 3                                                 NaN             Tổng số
# 4                                                 NaN           (Tỷ đồng)
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN       3142295.86591
# 8                                                 NaN       342159.902316
# 9                                         Nông nghiệp              263046
# 10                                         Lâm nghiệp               12939
# 11                                           Thủy sản               66175
# 12                                                NaN      1167284.962749
# 13                                        Công nghiệp      1008603.187686
# 14                                        Khai khoáng        84319.441721
# 15                      Công nghiệp chế biến, chế tạo       760494.644296
# 16  Sản xuất và phân phối điện, khí đốt, \nnước nó...       148603.353947
# 17  Cung cấp nước; hoạt động quản lý\nvà xử lý rác...        15185.747721
# 18                                           Xây dựng       158681.775063
# 19                                                NaN      1365455.153002
# 20  Bán buôn và bán lẻ; sửa chữa ô tô, mô tô, \nxe...       334305.900799
# 21                                   Vận tải, kho bãi       177929.190865
# 22                         Dịch vụ lưu trú và ăn uống        91654.687298
# 23                          Thông tin và truyền thông       104311.575849
# 24         Hoạt động tài chính, ngân hàng và bảo hiểm       147576.697176
# 25                  Hoạt động kinh doanh bất động sản        107318.88634
# 26        Hoạt động chuyên môn, khoa học và công nghệ        60311.118081
# 27             Hoạt động hành chính và dịch vụ hỗ trợ        42889.958925
# 28  Hoạt động của Đảng Cộng sản, tổ chức\nchính tr...        56833.314248
# 29                                Giáo dục và đào tạo       115793.047971
# 30                  Y tế và hoạt động trợ giúp xã hội        77075.141459
# 31                   Nghệ thuật, vui chơi và giải trí        21069.951839
# 32                             Hoạt động dịch vụ khác         23946.46158
# 33  Hoạt động làm thuê các công việc trong các \nh...         4439.220573
# 34                                                NaN       267395.847842
#
#             3   4                      5             6
# 0         NaN NaN                    NaN           NaN
# 1         NaN NaN                    NaN           NaN
# 2         NaN NaN  Theo giá so sánh 2020           NaN
# 3      Cơ cấu NaN                Tổng số   Tốc độ tăng
# 4         (%) NaN              (Tỷ đồng)  so với quý I
# 5         NaN NaN                    NaN  năm 2025 (%)
# 6         NaN NaN                    NaN           NaN
# 7         100 NaN          2589918.33923      7.826245
# 8   10.888851 NaN          280313.977505      3.577216
# 9     8.37114 NaN                 213425          3.36
# 10   0.411769 NaN                  11809          3.22
# 11   2.105944 NaN                  55080          4.51
# 12  37.147519 NaN          930262.756066      8.921801
# 13  32.097652 NaN          801680.819773      9.011898
# 14   2.683371 NaN           47476.279623      5.421173
# 15  24.201879 NaN          633977.135141      9.729336
# 16   4.729133 NaN          106531.309634      6.538113
# 17   0.483269 NaN           13696.095375      8.580657
# 18   5.049867 NaN          128581.936293      8.363402
# 19  43.454061 NaN         1150827.263702      8.177337
# 20  10.638906 NaN          286130.807607      9.617395
# 21   5.662395 NaN          146231.761911      8.948405
# 22   2.916806 NaN           71707.336323      7.486755
# 23   3.319598 NaN          102383.915114       7.64938
# 24   4.696461 NaN          122995.890381      7.704538
# 25   3.415302 NaN           84810.105239      4.710028
# 26   1.919333 NaN           55948.293647      8.006391
# 27   1.364924 NaN            38886.10585      7.063905
# 28   1.808656 NaN           49860.066543          9.62
# 29   3.684982 NaN           91771.856596      8.251461
# 30   2.452829 NaN           58459.584971      6.902466
# 31   0.670527 NaN           19170.987091      9.715914
# 32   0.762069 NaN           18984.970059      6.749342
# 33   0.141273 NaN             3485.58237          7.36
# 34   8.509569 NaN          228514.341957          7.08
